# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Графики интерполяционных полиномов

# %%
def smooth(x):
    return 3 * x - 14 + np.exp(-x)

# %%
def breakdown(x):
    return abs(x - np.log(2)) * np.sin(x) + 1

# %%
x = np.linspace(-4, 5, 1000)
y_smooth = smooth(x)

plt.plot(x, y_smooth, color='r', label='Гладкая функция')

plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()

# %%
y_breakdown = breakdown(x)
plt.plot(x, y_breakdown, color='b', label='Функция с разрывом производной')
plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## $y = 3x - 14 + e^{-x}$

# %% [markdown]
# ### Чебышевская сетка

# %%
data = pd.read_csv("data/chebyshev_smooth_2.csv")
x = data['x']
y_function = smooth(x)

plt.plot(x, y_function, color='black', linestyle='--', label='$f(x)$', linewidth=3)
colors = ['r', 'g', 'b', 'orange']

for i in range(2, 9, 2):
    name = "data/chebyshev_smooth_" + str(i) + ".csv"
    label = str(i)
    if (i < 5):
        label += ' узла'
    else:
        label += ' узлов'
    data = pd.read_csv(name)
    y_inter = data['y']
    plt.plot(x, y_inter, color=colors[i // 2 - 1], label=label)

plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Равномерная сетка

# %%
data = pd.read_csv("data/uniform_smooth_2.csv")
x = data['x']
y_function = smooth(x)

plt.plot(x, y_function, color='black', linestyle='--', label='$f(x)$', linewidth=3)
colors = ['r', 'g', 'b', 'orange']

for i in range(2, 9, 2):
    name = "data/uniform_smooth_" + str(i) + ".csv"
    label = str(i)
    if (i < 5):
        label += ' узла'
    else:
        label += ' узлов'
    data = pd.read_csv(name)
    y_inter = data['y']
    plt.plot(x, y_inter, color=colors[i // 2 - 1], label=label)

plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## $y = |x - ln(2)|sin(x) + 1$

# %% [markdown]
# ### Чебышевская сетка

# %%
data = pd.read_csv("data/chebyshev_breakdown_2.csv")
x = data['x']
y_function = breakdown(x)

plt.plot(x, y_function, color='black', linestyle='--', label='$g(x)$', linewidth=3)
colors = ['r', 'g', 'b', 'orange']

for i in range(2, 9, 2):
    name = "data/chebyshev_breakdown_" + str(i) + ".csv"
    label = str(i)
    if (i < 5):
        label += ' узла'
    else:
        label += ' узлов'
    data = pd.read_csv(name)
    y_inter = data['y']
    plt.plot(x, y_inter, color=colors[i // 2 - 1], label=label)

plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ### Равномерная сетка

# %%
data = pd.read_csv("data/uniform_breakdown_2.csv")
x = data['x']
y_function = breakdown(x)

plt.plot(x, y_function, color='black', linestyle='--', label='$g(x)$', linewidth=3)
colors = ['r', 'g', 'b', 'orange']

for i in range(2, 9, 2):
    name = "data/uniform_breakdown_" + str(i) + ".csv"
    label = str(i)
    if (i < 5):
        label += ' узла'
    else:
        label += ' узлов'
    data = pd.read_csv(name)
    y_inter = data['y']
    plt.plot(x, y_inter, color=colors[i // 2 - 1], label=label)

plt.xlabel('x')
plt.ylabel('y')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# # Зависимость погрешности от количества узлов

# %% [markdown]
# ## $y = 3x - 14 + e^{-x}$

# %%
data = pd.read_csv("data/nodes_error_chebyshev_smooth.csv")
nodes = data['nodes']
error = data['error']


plt.plot(nodes, error, color='r', label='Чебышевская сетка')

data = pd.read_csv("data/nodes_error_uniform_smooth.csv")
nodes = data['nodes']
error = data['error']


plt.plot(nodes, error, color='b', label='Равномерная сетка')
plt.xlabel('nodes')
plt.ylabel('error')
plt.xticks(range(1, 33, 5))
plt.yscale('log')
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# ## $y = |x - ln(2)|sin(x) + 1$

# %%
data = pd.read_csv("data/nodes_error_chebyshev_breakdown.csv")
nodes = data['nodes']
error = data['error']


plt.plot(nodes, error, color='r', label='Чебышевская сетка')

data = pd.read_csv("data/nodes_error_uniform_breakdown.csv")
nodes = data['nodes']
error = data['error']


plt.plot(nodes, error, color='b', label='Равномерная сетка')
plt.xlabel('nodes')
plt.ylabel('error')
plt.xticks(range(1, 33, 5))
plt.yscale('log')
plt.grid(True)
plt.legend()
plt.show()
